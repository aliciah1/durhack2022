# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("OPEN_CLOSE_DATASET1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DataMessageGUID  1032 non-null   object
#  1   SensorID         1032 non-null   int64
#  2   Sensor Name      1032 non-null   object
#  3   Date             1032 non-null   object
#  4   Value            1032 non-null   int64
#  5   Formatted Value  1032 non-null   object
#  6   Battery          1032 non-null   int64
#  7   Raw Data         1032 non-null   bool
#  8   Sensor State     1032 non-null   int64
#  9   GatewayID        1032 non-null   int64
#  10  Alert Sent       1032 non-null   bool
#  11  Signal Strength  1032 non-null   int64
#  12  Voltage          1032 non-null   float64
# dtypes: bool(2), float64(1), int64(6), object(4)
# memory usage: 90.8+ KB

# %%
n = 19
df.drop(index=df.index[:n],inplace=True)
print(df)
# Out:
#                            DataMessageGUID  SensorID      Sensor Name  \
# 19    f7214889-cbed-4dd9-9557-9e9bf330188f    829993  Open / Closed 1
# 20    35dd3cd2-d60c-4f06-a199-7872c23a677d    829993  Open / Closed 1
# 21    12589f26-dc50-402c-9553-d91fd7db5a54    829993  Open / Closed 1
# 22    175a74a1-1167-4516-891e-7ebbacc697e4    829993  Open / Closed 1
# 23    de2c54ee-a4ed-49c0-817e-408c1236d41e    829993  Open / Closed 1
# ...                                    ...       ...              ...
# 1027  2a2c7652-8b78-4862-9925-a7ae899be532    829993  Open / Closed 1
# 1028  3d3cd0ae-8c6f-47d8-a02b-a36cee47ff48    829993  Open / Closed 1
# 1029  2ceed47e-cde5-4775-b47e-6ab377d78e05    829993  Open / Closed 1
# 1030  8b36ed94-2b38-404e-b706-07bbf014d3c7    829993  Open / Closed 1
# 1031  37bd1b59-44a6-44d1-be22-550449de301f    829993  Open / Closed 1
#
#                      Date  Value Formatted Value  Battery  Raw Data  \
# 19     11/18/2022 9:13 PM      1          Closed      100      True
# 20     11/18/2022 8:13 PM      1          Closed      100      True
# 21     11/18/2022 8:13 PM      0            Open      100     False
# 22     11/18/2022 7:47 PM      1          Closed      100      True
# 23     11/18/2022 7:47 PM      0            Open      100     False
# ...                   ...    ...             ...      ...       ...
# 1027   11/14/2022 4:12 AM      1          Closed      100      True
# 1028   11/14/2022 3:12 AM      1          Closed      100      True
# 1029   11/14/2022 2:12 AM      1          Closed      100      True
# 1030   11/14/2022 1:12 AM      1          Closed      100      True
# 1031  11/14/2022 12:12 AM      1          Closed      100      True
#
#       Sensor State  GatewayID  Alert Sent  Signal Strength  Voltage
# 19               0     964010       False               77     2.66
# 20               0     964010       False               79     2.66
# 21               2     964010       False               76     2.66
# 22               0     964010       False               80     2.66
# 23               2     964010       False               74     2.66
# ...            ...        ...         ...              ...      ...
# 1027             0     964010       False              100     2.64
# 1028             0     964010       False              100     2.64
# 1029             0     964010       False              100     2.64
# 1030             0     964010       False              100     2.64
# 1031             0     964010       False              100     2.64
#
# [1013 rows x 13 columns]

# %%
n = 791
df.drop(df.tail(n).index,
        inplace = True)
print(df)
# Out:
#                           DataMessageGUID  SensorID      Sensor Name  \
# 19   f7214889-cbed-4dd9-9557-9e9bf330188f    829993  Open / Closed 1
# 20   35dd3cd2-d60c-4f06-a199-7872c23a677d    829993  Open / Closed 1
# 21   12589f26-dc50-402c-9553-d91fd7db5a54    829993  Open / Closed 1
# 22   175a74a1-1167-4516-891e-7ebbacc697e4    829993  Open / Closed 1
# 23   de2c54ee-a4ed-49c0-817e-408c1236d41e    829993  Open / Closed 1
# ..                                    ...       ...              ...
# 236  fb39001d-37c8-47a8-b3ff-812b64eee5e5    829993  Open / Closed 1
# 237  4e41ad40-c6b9-47c8-b439-bf4ab3672668    829993  Open / Closed 1
# 238  2ebeedea-16a4-4deb-9ec1-8908e63d2a6e    829993  Open / Closed 1
# 239  14864dfe-a482-4178-9527-bdda40678fb6    829993  Open / Closed 1
# 240  c7a0d277-9cfd-4946-9020-99cb41164f31    829993  Open / Closed 1
#
#                    Date  Value Formatted Value  Battery  Raw Data  \
# 19   11/18/2022 9:13 PM      1          Closed      100      True
# 20   11/18/2022 8:13 PM      1          Closed      100      True
# 21   11/18/2022 8:13 PM      0            Open      100     False
# 22   11/18/2022 7:47 PM      1          Closed      100      True
# 23   11/18/2022 7:47 PM      0            Open      100     False
# ..                  ...    ...             ...      ...       ...
# 236  11/18/2022 9:35 AM      1          Closed      100      True
# 237  11/18/2022 9:34 AM      0            Open      100     False
# 238  11/18/2022 9:25 AM      1          Closed      100      True
# 239  11/18/2022 9:25 AM      0            Open      100     False
# 240  11/18/2022 9:23 AM      1          Closed      100      True
#
#      Sensor State  GatewayID  Alert Sent  Signal Strength  Voltage
# 19              0     964010       False               77     2.66
# 20              0     964010       False               79     2.66
# 21              2     964010       False               76     2.66
# 22              0     964010       False               80     2.66
# 23              2     964010       False               74     2.66
# ..            ...        ...         ...              ...      ...
# 236             0     964010       False               80     2.66
# 237             2     964010       False               77     2.66
# 238             0     964010       False               81     2.66
# 239             2     964010       False               80     2.66
# 240             0     964010       False               78     2.66
#
# [222 rows x 13 columns]

# %%
print(df)
# Out:
#                           DataMessageGUID  SensorID      Sensor Name  \
# 19   f7214889-cbed-4dd9-9557-9e9bf330188f    829993  Open / Closed 1
# 20   35dd3cd2-d60c-4f06-a199-7872c23a677d    829993  Open / Closed 1
# 21   12589f26-dc50-402c-9553-d91fd7db5a54    829993  Open / Closed 1
# 22   175a74a1-1167-4516-891e-7ebbacc697e4    829993  Open / Closed 1
# 23   de2c54ee-a4ed-49c0-817e-408c1236d41e    829993  Open / Closed 1
# ..                                    ...       ...              ...
# 236  fb39001d-37c8-47a8-b3ff-812b64eee5e5    829993  Open / Closed 1
# 237  4e41ad40-c6b9-47c8-b439-bf4ab3672668    829993  Open / Closed 1
# 238  2ebeedea-16a4-4deb-9ec1-8908e63d2a6e    829993  Open / Closed 1
# 239  14864dfe-a482-4178-9527-bdda40678fb6    829993  Open / Closed 1
# 240  c7a0d277-9cfd-4946-9020-99cb41164f31    829993  Open / Closed 1
#
#                    Date  Value Formatted Value  Battery  Raw Data  \
# 19   11/18/2022 9:13 PM      1          Closed      100      True
# 20   11/18/2022 8:13 PM      1          Closed      100      True
# 21   11/18/2022 8:13 PM      0            Open      100     False
# 22   11/18/2022 7:47 PM      1          Closed      100      True
# 23   11/18/2022 7:47 PM      0            Open      100     False
# ..                  ...    ...             ...      ...       ...
# 236  11/18/2022 9:35 AM      1          Closed      100      True
# 237  11/18/2022 9:34 AM      0            Open      100     False
# 238  11/18/2022 9:25 AM      1          Closed      100      True
# 239  11/18/2022 9:25 AM      0            Open      100     False
# 240  11/18/2022 9:23 AM      1          Closed      100      True
#
#      Sensor State  GatewayID  Alert Sent  Signal Strength  Voltage
# 19              0     964010       False               77     2.66
# 20              0     964010       False               79     2.66
# 21              2     964010       False               76     2.66
# 22              0     964010       False               80     2.66
# 23              2     964010       False               74     2.66
# ..            ...        ...         ...              ...      ...
# 236             0     964010       False               80     2.66
# 237             2     964010       False               77     2.66
# 238             0     964010       False               81     2.66
# 239             2     964010       False               80     2.66
# 240             0     964010       False               78     2.66
#
# [222 rows x 13 columns]

# %%
df.head()
# Out:
#                          DataMessageGUID  SensorID      Sensor Name  \
# 19  f7214889-cbed-4dd9-9557-9e9bf330188f    829993  Open / Closed 1
# 20  35dd3cd2-d60c-4f06-a199-7872c23a677d    829993  Open / Closed 1
# 21  12589f26-dc50-402c-9553-d91fd7db5a54    829993  Open / Closed 1
# 22  175a74a1-1167-4516-891e-7ebbacc697e4    829993  Open / Closed 1
# 23  de2c54ee-a4ed-49c0-817e-408c1236d41e    829993  Open / Closed 1
#
#                   Date  Value Formatted Value  Battery  Raw Data  \
# 19  11/18/2022 9:13 PM      1          Closed      100      True
# 20  11/18/2022 8:13 PM      1          Closed      100      True
# 21  11/18/2022 8:13 PM      0            Open      100     False
# 22  11/18/2022 7:47 PM      1          Closed      100      True
# 23  11/18/2022 7:47 PM      0            Open      100     False
#
#     Sensor State  GatewayID  Alert Sent  Signal Strength  Voltage
# 19             0     964010       False               77     2.66
# 20             0     964010       False               79     2.66
# 21             2     964010       False               76     2.66
# 22             0     964010       False               80     2.66
# 23             2     964010       False               74     2.66

# %%
df.drop("DataMessageGUID", axis = 1, inplace = True)
df.drop("SensorID", axis = 1, inplace = True)
df.drop("Sensor Name", axis = 1, inplace = True)
df.drop("Battery", axis = 1, inplace = True)
df.drop("GatewayID", axis = 1, inplace = True)
df.drop("Signal Strength", axis = 1, inplace = True)

# %%
df.head()
# Out:
#                   Date  Value Formatted Value  Raw Data  Sensor State  \
# 19  11/18/2022 9:13 PM      1          Closed      True             0
# 20  11/18/2022 8:13 PM      1          Closed      True             0
# 21  11/18/2022 8:13 PM      0            Open     False             2
# 22  11/18/2022 7:47 PM      1          Closed      True             0
# 23  11/18/2022 7:47 PM      0            Open     False             2
#
#     Alert Sent  Voltage
# 19       False     2.66
# 20       False     2.66
# 21       False     2.66
# 22       False     2.66
# 23       False     2.66

# %%
print(df)
# Out:
#                    Date  Value Formatted Value  Raw Data  Sensor State  \
# 19   11/18/2022 9:13 PM      1          Closed      True             0
# 20   11/18/2022 8:13 PM      1          Closed      True             0
# 21   11/18/2022 8:13 PM      0            Open     False             2
# 22   11/18/2022 7:47 PM      1          Closed      True             0
# 23   11/18/2022 7:47 PM      0            Open     False             2
# ..                  ...    ...             ...       ...           ...
# 236  11/18/2022 9:35 AM      1          Closed      True             0
# 237  11/18/2022 9:34 AM      0            Open     False             2
# 238  11/18/2022 9:25 AM      1          Closed      True             0
# 239  11/18/2022 9:25 AM      0            Open     False             2
# 240  11/18/2022 9:23 AM      1          Closed      True             0
#
#      Alert Sent  Voltage
# 19        False     2.66
# 20        False     2.66
# 21        False     2.66
# 22        False     2.66
# 23        False     2.66
# ..          ...      ...
# 236       False     2.66
# 237       False     2.66
# 238       False     2.66
# 239       False     2.66
# 240       False     2.66
#
# [222 rows x 7 columns]

# %%
df.describe()
#IMPORTANT
# Out:
#             Value  Sensor State     Voltage
# count  222.000000    222.000000  222.000000
# mean     0.495495      1.009009    2.662207
# std      0.501110      1.002219    0.004264
# min      0.000000      0.000000    2.650000
# 25%      0.000000      0.000000    2.660000
# 50%      0.000000      2.000000    2.660000
# 75%      1.000000      2.000000    2.660000
# max      1.000000      2.000000    2.670000

# %%
df.head()
# Out:
#                   Date  Value Formatted Value  Raw Data  Sensor State  \
# 19  11/18/2022 9:13 PM      1          Closed      True             0
# 20  11/18/2022 8:13 PM      1          Closed      True             0
# 21  11/18/2022 8:13 PM      0            Open     False             2
# 22  11/18/2022 7:47 PM      1          Closed      True             0
# 23  11/18/2022 7:47 PM      0            Open     False             2
#
#     Alert Sent  Voltage
# 19       False     2.66
# 20       False     2.66
# 21       False     2.66
# 22       False     2.66
# 23       False     2.66

# %%
print(df[df.Value == df.Value.max()])
# Out:
#                    Date  Value Formatted Value  Raw Data  Sensor State  \
# 19   11/18/2022 9:13 PM      1          Closed      True             0
# 20   11/18/2022 8:13 PM      1          Closed      True             0
# 22   11/18/2022 7:47 PM      1          Closed      True             0
# 24   11/18/2022 7:47 PM      1          Closed      True             0
# 26   11/18/2022 7:46 PM      1          Closed      True             0
# ..                  ...    ...             ...       ...           ...
# 232  11/18/2022 9:38 AM      1          Closed      True             0
# 234  11/18/2022 9:37 AM      1          Closed      True             0
# 236  11/18/2022 9:35 AM      1          Closed      True             0
# 238  11/18/2022 9:25 AM      1          Closed      True             0
# 240  11/18/2022 9:23 AM      1          Closed      True             0
#
#      Alert Sent  Voltage
# 19        False     2.66
# 20        False     2.66
# 22        False     2.66
# 24        False     2.66
# 26        False     2.66
# ..          ...      ...
# 232       False     2.66
# 234       False     2.66
# 236       False     2.66
# 238       False     2.66
# 240       False     2.66
#
# [110 rows x 7 columns]

# %%
print(df[df.Value == df.Value.max()])
# Out:
#                    Date  Value Formatted Value  Raw Data  Sensor State  \
# 19   11/18/2022 9:13 PM      1          Closed      True             0
# 20   11/18/2022 8:13 PM      1          Closed      True             0
# 22   11/18/2022 7:47 PM      1          Closed      True             0
# 24   11/18/2022 7:47 PM      1          Closed      True             0
# 26   11/18/2022 7:46 PM      1          Closed      True             0
# ..                  ...    ...             ...       ...           ...
# 232  11/18/2022 9:38 AM      1          Closed      True             0
# 234  11/18/2022 9:37 AM      1          Closed      True             0
# 236  11/18/2022 9:35 AM      1          Closed      True             0
# 238  11/18/2022 9:25 AM      1          Closed      True             0
# 240  11/18/2022 9:23 AM      1          Closed      True             0
#
#      Alert Sent  Voltage
# 19        False     2.66
# 20        False     2.66
# 22        False     2.66
# 24        False     2.66
# 26        False     2.66
# ..          ...      ...
# 232       False     2.66
# 234       False     2.66
# 236       False     2.66
# 238       False     2.66
# 240       False     2.66
#
# [110 rows x 7 columns]

# %%
print(df[df.Value == df.Value.min()])
# Out:
#                    Date  Value Formatted Value  Raw Data  Sensor State  \
# 21   11/18/2022 8:13 PM      0            Open     False             2
# 23   11/18/2022 7:47 PM      0            Open     False             2
# 25   11/18/2022 7:47 PM      0            Open     False             2
# 27   11/18/2022 7:46 PM      0            Open     False             2
# 29   11/18/2022 7:45 PM      0            Open     False             2
# ..                  ...    ...             ...       ...           ...
# 231  11/18/2022 9:43 AM      0            Open     False             2
# 233  11/18/2022 9:38 AM      0            Open     False             2
# 235  11/18/2022 9:37 AM      0            Open     False             2
# 237  11/18/2022 9:34 AM      0            Open     False             2
# 239  11/18/2022 9:25 AM      0            Open     False             2
#
#      Alert Sent  Voltage
# 21        False     2.66
# 23        False     2.66
# 25        False     2.66
# 27        False     2.67
# 29        False     2.66
# ..          ...      ...
# 231       False     2.66
# 233       False     2.66
# 235       False     2.66
# 237       False     2.66
# 239       False     2.66
#
# [112 rows x 7 columns]

# %%
print(df[df.Value == df.Value.median()])
# Out:
#                    Date  Value Formatted Value  Raw Data  Sensor State  \
# 21   11/18/2022 8:13 PM      0            Open     False             2
# 23   11/18/2022 7:47 PM      0            Open     False             2
# 25   11/18/2022 7:47 PM      0            Open     False             2
# 27   11/18/2022 7:46 PM      0            Open     False             2
# 29   11/18/2022 7:45 PM      0            Open     False             2
# ..                  ...    ...             ...       ...           ...
# 231  11/18/2022 9:43 AM      0            Open     False             2
# 233  11/18/2022 9:38 AM      0            Open     False             2
# 235  11/18/2022 9:37 AM      0            Open     False             2
# 237  11/18/2022 9:34 AM      0            Open     False             2
# 239  11/18/2022 9:25 AM      0            Open     False             2
#
#      Alert Sent  Voltage
# 21        False     2.66
# 23        False     2.66
# 25        False     2.66
# 27        False     2.67
# 29        False     2.66
# ..          ...      ...
# 231       False     2.66
# 233       False     2.66
# 235       False     2.66
# 237       False     2.66
# 239       False     2.66
#
# [112 rows x 7 columns]
