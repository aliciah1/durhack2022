# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("VIBRATION.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486 entries, 0 to 485
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DataMessageGUID  486 non-null    object
#  1   SensorID         486 non-null    int64
#  2   Sensor Name      486 non-null    object
#  3   Date             486 non-null    object
#  4   Value            486 non-null    float64
#  5   Formatted Value  486 non-null    object
#  6   Battery          486 non-null    int64
#  7   Raw Data         486 non-null    object
#  8   Sensor State     486 non-null    int64
#  9   GatewayID        486 non-null    int64
#  10  Alert Sent       486 non-null    bool
#  11  Signal Strength  486 non-null    int64
#  12  Voltage          486 non-null    float64
# dtypes: bool(1), float64(2), int64(5), object(5)
# memory usage: 46.2+ KB

# %%
n = 20
df.drop(index=df.index[:n],inplace=True)
print(df)
# Out:
#                           DataMessageGUID  SensorID        Sensor Name  \
# 20   b53aa5a8-4433-4094-b8fd-35967a6668fa    814111  Vibration Meter 1
# 21   d1778d42-a721-46a5-8ca6-0fd73e7af253    814111  Vibration Meter 1
# 22   d3ade6e8-f2ab-4804-82b3-8ed0d79a2495    814111  Vibration Meter 1
# 23   6732aa8c-0b40-47c5-b853-f9bd36416340    814111  Vibration Meter 1
# 24   2d414498-cf5d-4d55-849c-01c426d4ac22    814111  Vibration Meter 1
# ..                                    ...       ...                ...
# 481  ffe8fac5-6680-4749-8ead-1137121c9f35    814111  Vibration Meter 1
# 482  bfe5709d-8177-4691-b0a6-ee84641de7d4    814111  Vibration Meter 1
# 483  0efdd662-aadd-4282-9152-184b618fd667    814111  Vibration Meter 1
# 484  95b036ea-76dc-43b5-8acb-7edc0670f16c    814111  Vibration Meter 1
# 485  c3b085f0-700c-4ba4-8bc3-0acefc9cfd77    814111  Vibration Meter 1
#
#                    Date  Value  \
# 20   11/18/2022 7:50 PM    0.5
# 21   11/18/2022 7:40 PM    0.5
# 22   11/18/2022 7:30 PM    0.5
# 23   11/18/2022 7:20 PM    0.5
# 24   11/18/2022 7:10 PM    0.5
# ..                  ...    ...
# 481  11/14/2022 7:00 AM    0.0
# 482  11/14/2022 6:30 AM    0.0
# 483  11/14/2022 6:00 AM    0.0
# 484  11/14/2022 5:30 AM    0.0
# 485  11/14/2022 5:00 AM    0.0
#
#                                        Formatted Value  Battery  \
# 20   X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.8 mm/s 11 Hz, ...      100
# 21   X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.8 mm/s 10 Hz, ...      100
# 22   X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.8 mm/s 11 Hz, ...      100
# 23   X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 15 Hz, ...      100
# 24   X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.8 mm/s 14 Hz, ...      100
# ..                                                 ...      ...
# 481  X-Axis 0 mm/s 0 Hz, Y-Axis 0 mm/s 0 Hz, Z-Axis...      100
# 482  X-Axis 0 mm/s 0 Hz, Y-Axis 0 mm/s 0 Hz, Z-Axis...      100
# 483  X-Axis 0 mm/s 0 Hz, Y-Axis 0 mm/s 0 Hz, Z-Axis...      100
# 484  X-Axis 0 mm/s 0 Hz, Y-Axis 0 mm/s 0 Hz, Z-Axis...      100
# 485  X-Axis 0 mm/s 0 Hz, Y-Axis 0 mm/s 0 Hz, Z-Axis...      100
#
#                        Raw Data  Sensor State  GatewayID  Alert Sent  \
# 20   0.5|0.8|0.6|13|11|14|100|2             2     964010       False
# 21   0.5|0.8|0.5|11|10|13|100|2             2     964010       False
# 22   0.5|0.8|0.6|12|11|12|100|2             2     964010       False
# 23   0.5|0.7|0.5|13|15|13|100|2             2     964010       False
# 24   0.5|0.8|0.6|14|14|12|100|2             2     964010       False
# ..                          ...           ...        ...         ...
# 481             0|0|0|0|0|0|0|0             0     964010       False
# 482             0|0|0|0|0|0|0|0             0     964010       False
# 483             0|0|0|0|0|0|0|0             0     964010       False
# 484             0|0|0|0|0|0|0|0             0     964010       False
# 485             0|0|0|0|0|0|0|0             0     964010       False
#
#      Signal Strength  Voltage
# 20               100     2.96
# 21               100     2.96
# 22               100     2.96
# 23               100     2.96
# 24               100     2.96
# ..               ...      ...
# 481              100     2.99
# 482              100     2.98
# 483              100     2.98
# 484              100     2.94
# 485              100     2.98
#
# [466 rows x 13 columns]

# %%
n = 393
df.drop(df.tail(n).index,
        inplace = True)
print(df)
# Out:
#                          DataMessageGUID  SensorID        Sensor Name  \
# 20  b53aa5a8-4433-4094-b8fd-35967a6668fa    814111  Vibration Meter 1
# 21  d1778d42-a721-46a5-8ca6-0fd73e7af253    814111  Vibration Meter 1
# 22  d3ade6e8-f2ab-4804-82b3-8ed0d79a2495    814111  Vibration Meter 1
# 23  6732aa8c-0b40-47c5-b853-f9bd36416340    814111  Vibration Meter 1
# 24  2d414498-cf5d-4d55-849c-01c426d4ac22    814111  Vibration Meter 1
# ..                                   ...       ...                ...
# 88  45abc3c3-73bf-47c2-9eff-6ec34baddbce    814111  Vibration Meter 1
# 89  8e27c23a-ecf6-4845-8997-693e40a59e8f    814111  Vibration Meter 1
# 90  33306a32-801b-436b-90a5-37af9b183b5f    814111  Vibration Meter 1
# 91  2c61edf6-ae56-4b0d-a2f1-284f20d0ae73    814111  Vibration Meter 1
# 92  7dc23de5-e004-441e-9b3d-85a99cc13475    814111  Vibration Meter 1
#
#                   Date  Value  \
# 20  11/18/2022 7:50 PM    0.5
# 21  11/18/2022 7:40 PM    0.5
# 22  11/18/2022 7:30 PM    0.5
# 23  11/18/2022 7:20 PM    0.5
# 24  11/18/2022 7:10 PM    0.5
# ..                 ...    ...
# 88  11/18/2022 8:30 AM    0.5
# 89  11/18/2022 8:20 AM    0.5
# 90  11/18/2022 8:10 AM    0.5
# 91  11/18/2022 8:00 AM    0.5
# 92  11/18/2022 7:50 AM    0.5
#
#                                       Formatted Value  Battery  \
# 20  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.8 mm/s 11 Hz, ...      100
# 21  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.8 mm/s 10 Hz, ...      100
# 22  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.8 mm/s 11 Hz, ...      100
# 23  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 15 Hz, ...      100
# 24  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.8 mm/s 14 Hz, ...      100
# ..                                                ...      ...
# 88  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.6 mm/s 12 Hz, ...      100
# 89  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.6 mm/s 14 Hz, ...      100
# 90  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.6 mm/s 14 Hz, ...      100
# 91  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.6 mm/s 14 Hz, ...      100
# 92  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 13 Hz, ...      100
#
#                       Raw Data  Sensor State  GatewayID  Alert Sent  \
# 20  0.5|0.8|0.6|13|11|14|100|2             2     964010       False
# 21  0.5|0.8|0.5|11|10|13|100|2             2     964010       False
# 22  0.5|0.8|0.6|12|11|12|100|2             2     964010       False
# 23  0.5|0.7|0.5|13|15|13|100|2             2     964010       False
# 24  0.5|0.8|0.6|14|14|12|100|2             2     964010       False
# ..                         ...           ...        ...         ...
# 88  0.5|0.6|0.5|14|12|14|100|2             2     964010       False
# 89  0.5|0.6|0.5|13|14|11|100|2             2     964010       False
# 90  0.5|0.6|0.5|12|14|15|100|2             2     964010       False
# 91  0.5|0.6|0.5|11|14|12|100|2             2     964010       False
# 92  0.5|0.7|0.5|13|13|12|100|2             2     964010       False
#
#     Signal Strength  Voltage
# 20              100     2.96
# 21              100     2.96
# 22              100     2.96
# 23              100     2.96
# 24              100     2.96
# ..              ...      ...
# 88              100     2.96
# 89              100     2.96
# 90              100     2.96
# 91              100     2.96
# 92              100     2.96
#
# [73 rows x 13 columns]

# %%
df.head()
# Out:
#                          DataMessageGUID  SensorID        Sensor Name  \
# 20  b53aa5a8-4433-4094-b8fd-35967a6668fa    814111  Vibration Meter 1
# 21  d1778d42-a721-46a5-8ca6-0fd73e7af253    814111  Vibration Meter 1
# 22  d3ade6e8-f2ab-4804-82b3-8ed0d79a2495    814111  Vibration Meter 1
# 23  6732aa8c-0b40-47c5-b853-f9bd36416340    814111  Vibration Meter 1
# 24  2d414498-cf5d-4d55-849c-01c426d4ac22    814111  Vibration Meter 1
#
#                   Date  Value  \
# 20  11/18/2022 7:50 PM    0.5
# 21  11/18/2022 7:40 PM    0.5
# 22  11/18/2022 7:30 PM    0.5
# 23  11/18/2022 7:20 PM    0.5
# 24  11/18/2022 7:10 PM    0.5
#
#                                       Formatted Value  Battery  \
# 20  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.8 mm/s 11 Hz, ...      100
# 21  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.8 mm/s 10 Hz, ...      100
# 22  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.8 mm/s 11 Hz, ...      100
# 23  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 15 Hz, ...      100
# 24  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.8 mm/s 14 Hz, ...      100
#
#                       Raw Data  Sensor State  GatewayID  Alert Sent  \
# 20  0.5|0.8|0.6|13|11|14|100|2             2     964010       False
# 21  0.5|0.8|0.5|11|10|13|100|2             2     964010       False
# 22  0.5|0.8|0.6|12|11|12|100|2             2     964010       False
# 23  0.5|0.7|0.5|13|15|13|100|2             2     964010       False
# 24  0.5|0.8|0.6|14|14|12|100|2             2     964010       False
#
#     Signal Strength  Voltage
# 20              100     2.96
# 21              100     2.96
# 22              100     2.96
# 23              100     2.96
# 24              100     2.96

# %%
df.drop("DataMessageGUID", axis = 1, inplace = True)
df.drop("SensorID", axis = 1, inplace = True)
df.drop("Sensor Name", axis = 1, inplace = True)
df.drop("Battery", axis = 1, inplace = True)
df.drop("GatewayID", axis = 1, inplace = True)
df.drop("Signal Strength", axis = 1, inplace = True)

# %%
df.head()
# Out:
#                   Date  Value  \
# 20  11/18/2022 7:50 PM    0.5
# 21  11/18/2022 7:40 PM    0.5
# 22  11/18/2022 7:30 PM    0.5
# 23  11/18/2022 7:20 PM    0.5
# 24  11/18/2022 7:10 PM    0.5
#
#                                       Formatted Value  \
# 20  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 21  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.8 mm/s 10 Hz, ...
# 22  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 23  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 15 Hz, ...
# 24  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.8 mm/s 14 Hz, ...
#
#                       Raw Data  Sensor State  Alert Sent  Voltage
# 20  0.5|0.8|0.6|13|11|14|100|2             2       False     2.96
# 21  0.5|0.8|0.5|11|10|13|100|2             2       False     2.96
# 22  0.5|0.8|0.6|12|11|12|100|2             2       False     2.96
# 23  0.5|0.7|0.5|13|15|13|100|2             2       False     2.96
# 24  0.5|0.8|0.6|14|14|12|100|2             2       False     2.96

# %%
print(df)
# Out:
#                   Date  Value  \
# 20  11/18/2022 7:50 PM    0.5
# 21  11/18/2022 7:40 PM    0.5
# 22  11/18/2022 7:30 PM    0.5
# 23  11/18/2022 7:20 PM    0.5
# 24  11/18/2022 7:10 PM    0.5
# ..                 ...    ...
# 88  11/18/2022 8:30 AM    0.5
# 89  11/18/2022 8:20 AM    0.5
# 90  11/18/2022 8:10 AM    0.5
# 91  11/18/2022 8:00 AM    0.5
# 92  11/18/2022 7:50 AM    0.5
#
#                                       Formatted Value  \
# 20  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 21  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.8 mm/s 10 Hz, ...
# 22  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 23  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 15 Hz, ...
# 24  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.8 mm/s 14 Hz, ...
# ..                                                ...
# 88  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.6 mm/s 12 Hz, ...
# 89  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.6 mm/s 14 Hz, ...
# 90  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.6 mm/s 14 Hz, ...
# 91  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.6 mm/s 14 Hz, ...
# 92  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
#
#                       Raw Data  Sensor State  Alert Sent  Voltage
# 20  0.5|0.8|0.6|13|11|14|100|2             2       False     2.96
# 21  0.5|0.8|0.5|11|10|13|100|2             2       False     2.96
# 22  0.5|0.8|0.6|12|11|12|100|2             2       False     2.96
# 23  0.5|0.7|0.5|13|15|13|100|2             2       False     2.96
# 24  0.5|0.8|0.6|14|14|12|100|2             2       False     2.96
# ..                         ...           ...         ...      ...
# 88  0.5|0.6|0.5|14|12|14|100|2             2       False     2.96
# 89  0.5|0.6|0.5|13|14|11|100|2             2       False     2.96
# 90  0.5|0.6|0.5|12|14|15|100|2             2       False     2.96
# 91  0.5|0.6|0.5|11|14|12|100|2             2       False     2.96
# 92  0.5|0.7|0.5|13|13|12|100|2             2       False     2.96
#
# [73 rows x 7 columns]

# %%
df.describe()
#IMPORTANT
# Out:
#            Value  Sensor State    Voltage
# count  73.000000          73.0  73.000000
# mean    0.527397           2.0   2.960822
# std     0.050718           0.0   0.002766
# min     0.500000           2.0   2.960000
# 25%     0.500000           2.0   2.960000
# 50%     0.500000           2.0   2.960000
# 75%     0.500000           2.0   2.960000
# max     0.700000           2.0   2.970000

# %%
print(df[df.Value == df.Value.max()])
# Out:
#                   Date  Value  \
# 31  11/18/2022 6:00 PM    0.7
# 43  11/18/2022 4:00 PM    0.7
#
#                                       Formatted Value  \
# 31  X-Axis 0.7 mm/s 12 Hz, Y-Axis 1.6 mm/s 12 Hz, ...
# 43  X-Axis 0.7 mm/s 12 Hz, Y-Axis 1.7 mm/s 13 Hz, ...
#
#                       Raw Data  Sensor State  Alert Sent  Voltage
# 31  0.7|1.6|0.8|12|12|12|100|2             2       False     2.96
# 43  0.7|1.7|0.9|12|13|13|100|2             2       False     2.96

# %%
print(df[df.Value == df.Value.min()])
# Out:
#                    Date  Value  \
# 20   11/18/2022 7:50 PM    0.5
# 21   11/18/2022 7:40 PM    0.5
# 22   11/18/2022 7:30 PM    0.5
# 23   11/18/2022 7:20 PM    0.5
# 24   11/18/2022 7:10 PM    0.5
# 25   11/18/2022 7:00 PM    0.5
# 26   11/18/2022 6:50 PM    0.5
# 27   11/18/2022 6:40 PM    0.5
# 28   11/18/2022 6:30 PM    0.5
# 29   11/18/2022 6:20 PM    0.5
# 30   11/18/2022 6:10 PM    0.5
# 33   11/18/2022 5:40 PM    0.5
# 35   11/18/2022 5:20 PM    0.5
# 36   11/18/2022 5:10 PM    0.5
# 37   11/18/2022 5:00 PM    0.5
# 38   11/18/2022 4:50 PM    0.5
# 39   11/18/2022 4:40 PM    0.5
# 40   11/18/2022 4:30 PM    0.5
# 41   11/18/2022 4:20 PM    0.5
# 44   11/18/2022 3:50 PM    0.5
# 45   11/18/2022 3:40 PM    0.5
# 46   11/18/2022 3:30 PM    0.5
# 47   11/18/2022 3:20 PM    0.5
# 50   11/18/2022 2:50 PM    0.5
# 51   11/18/2022 2:40 PM    0.5
# 52   11/18/2022 2:30 PM    0.5
# 53   11/18/2022 2:20 PM    0.5
# 56   11/18/2022 1:50 PM    0.5
# 57   11/18/2022 1:40 PM    0.5
# 58   11/18/2022 1:30 PM    0.5
# 59   11/18/2022 1:20 PM    0.5
# 62  11/18/2022 12:50 PM    0.5
# 63  11/18/2022 12:40 PM    0.5
# 64  11/18/2022 12:30 PM    0.5
# 65  11/18/2022 12:20 PM    0.5
# 68  11/18/2022 11:50 AM    0.5
# 69  11/18/2022 11:40 AM    0.5
# 70  11/18/2022 11:30 AM    0.5
# 71  11/18/2022 11:20 AM    0.5
# 74  11/18/2022 10:50 AM    0.5
# 75  11/18/2022 10:40 AM    0.5
# 76  11/18/2022 10:30 AM    0.5
# 77  11/18/2022 10:20 AM    0.5
# 78  11/18/2022 10:10 AM    0.5
# 81   11/18/2022 9:40 AM    0.5
# 82   11/18/2022 9:30 AM    0.5
# 83   11/18/2022 9:20 AM    0.5
# 85   11/18/2022 9:00 AM    0.5
# 86   11/18/2022 8:50 AM    0.5
# 87   11/18/2022 8:40 AM    0.5
# 88   11/18/2022 8:30 AM    0.5
# 89   11/18/2022 8:20 AM    0.5
# 90   11/18/2022 8:10 AM    0.5
# 91   11/18/2022 8:00 AM    0.5
# 92   11/18/2022 7:50 AM    0.5
#
#                                       Formatted Value  \
# 20  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 21  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.8 mm/s 10 Hz, ...
# 22  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 23  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 15 Hz, ...
# 24  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.8 mm/s 14 Hz, ...
# 25  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 26  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.7 mm/s 16 Hz, ...
# 27  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 11 Hz, ...
# 28  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 12 Hz, ...
# 29  X-Axis 0.5 mm/s 15 Hz, Y-Axis 0.7 mm/s 15 Hz, ...
# 30  X-Axis 0.5 mm/s 10 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 33  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 35  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 36  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 37  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 14 Hz, ...
# 38  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 39  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.9 mm/s 12 Hz, ...
# 40  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.8 mm/s 10 Hz, ...
# 41  X-Axis 0.5 mm/s 10 Hz, Y-Axis 1 mm/s 11 Hz, Z-...
# 44  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.9 mm/s 12 Hz, ...
# 45  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.7 mm/s 14 Hz, ...
# 46  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 47  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 50  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.8 mm/s 13 Hz, ...
# 51  X-Axis 0.5 mm/s 15 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 52  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 53  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 56  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.8 mm/s 12 Hz, ...
# 57  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 12 Hz, ...
# 58  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.8 mm/s 12 Hz, ...
# 59  X-Axis 0.5 mm/s 16 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 62  X-Axis 0.5 mm/s 16 Hz, Y-Axis 0.8 mm/s 12 Hz, ...
# 63  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.8 mm/s 14 Hz, ...
# 64  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 15 Hz, ...
# 65  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 68  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 15 Hz, ...
# 69  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.8 mm/s 12 Hz, ...
# 70  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 71  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 74  X-Axis 0.5 mm/s 15 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 75  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 76  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 77  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 78  X-Axis 0.5 mm/s 15 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 81  X-Axis 0.5 mm/s 15 Hz, Y-Axis 0.8 mm/s 12 Hz, ...
# 82  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 83  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.8 mm/s 14 Hz, ...
# 85  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 14 Hz, ...
# 86  X-Axis 0.5 mm/s 10 Hz, Y-Axis 0.6 mm/s 12 Hz, ...
# 87  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 12 Hz, ...
# 88  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.6 mm/s 12 Hz, ...
# 89  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.6 mm/s 14 Hz, ...
# 90  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.6 mm/s 14 Hz, ...
# 91  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.6 mm/s 14 Hz, ...
# 92  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
#
#                       Raw Data  Sensor State  Alert Sent  Voltage
# 20  0.5|0.8|0.6|13|11|14|100|2             2       False     2.96
# 21  0.5|0.8|0.5|11|10|13|100|2             2       False     2.96
# 22  0.5|0.8|0.6|12|11|12|100|2             2       False     2.96
# 23  0.5|0.7|0.5|13|15|13|100|2             2       False     2.96
# 24  0.5|0.8|0.6|14|14|12|100|2             2       False     2.96
# 25  0.5|0.7|0.6|12|11|14|100|2             2       False     2.96
# 26  0.5|0.7|0.5|14|16|12|100|2             2       False     2.96
# 27  0.5|0.9|0.6|12|11|14|100|2             2       False     2.96
# 28  0.5|0.7|0.6|12|12|11|100|2             2       False     2.96
# 29  0.5|0.7|0.6|15|15|12|100|2             2       False     2.96
# 30  0.5|0.9|0.6|10|13|14|100|2             2       False     2.96
# 33  0.5|0.8|0.6|13|11|12|100|2             2       False     2.96
# 35  0.5|0.7|0.5|13|13|13|100|2             2       False     2.96
# 36  0.5|0.9|0.6|11|13|12|100|2             2       False     2.96
# 37  0.5|0.9|0.6|12|14|12|100|2             2       False     2.96
# 38  0.5|0.9|0.7|13|13|15|100|2             2       False     2.96
# 39  0.5|0.9|0.5|13|12|15|100|2             2       False     2.96
# 40  0.5|0.8|0.6|14|10|13|100|2             2       False     2.96
# 41    0.5|1|0.6|10|11|12|100|2             2       False     2.96
# 44  0.5|0.9|0.6|13|12|13|100|2             2       False     2.96
# 45  0.5|0.7|0.6|11|14|12|100|2             2       False     2.96
# 46  0.5|0.7|0.6|13|13|13|100|2             2       False     2.96
# 47  0.5|0.7|0.6|12|11|15|100|2             2       False     2.96
# 50  0.5|0.8|0.5|13|13|12|100|2             2       False     2.96
# 51  0.5|0.7|0.6|15|11|10|100|2             2       False     2.96
# 52  0.5|0.7|0.5|13|11|10|100|2             2       False     2.97
# 53  0.5|0.9|0.6|12|13|12|100|2             2       False     2.96
# 56  0.5|0.8|0.6|12|12|13|100|2             2       False     2.97
# 57  0.5|0.7|0.6|13|12|13|100|2             2       False     2.96
# 58  0.5|0.8|0.6|12|12|14|100|2             2       False     2.96
# 59  0.5|0.7|0.5|16|11|12|100|2             2       False     2.96
# 62  0.5|0.8|0.6|16|12|15|100|2             2       False     2.96
# 63  0.5|0.8|0.6|14|14|12|100|2             2       False     2.96
# 64  0.5|0.7|0.6|12|15|13|100|2             2       False     2.96
# 65  0.5|0.9|0.7|14|13|11|100|2             2       False     2.96
# 68  0.5|0.9|0.6|12|15|13|100|2             2       False     2.96
# 69  0.5|0.8|0.6|11|12|12|100|2             2       False     2.96
# 70  0.5|0.7|0.5|13|13|13|100|2             2       False     2.96
# 71  0.5|0.9|0.6|12|13|13|100|2             2       False     2.96
# 74  0.5|0.7|0.5|15|13|16|100|2             2       False     2.96
# 75  0.5|0.7|0.6|14|13|13|100|2             2       False     2.96
# 76  0.5|0.7|0.6|13|11|17|100|2             2       False     2.96
# 77  0.5|0.7|0.5|13|11|13|100|2             2       False     2.96
# 78  0.5|0.8|0.6|15|11|11|100|2             2       False     2.96
# 81  0.5|0.8|0.6|15|12|12|100|2             2       False     2.96
# 82  0.5|0.7|0.6|12|13|12|100|2             2       False     2.96
# 83  0.5|0.8|0.7|11|14|15|100|2             2       False     2.96
# 85  0.5|0.9|0.6|12|14|14|100|2             2       False     2.96
# 86  0.5|0.6|0.6|10|12|11|100|2             2       False     2.96
# 87  0.5|0.7|0.5|12|12|12|100|2             2       False     2.96
# 88  0.5|0.6|0.5|14|12|14|100|2             2       False     2.96
# 89  0.5|0.6|0.5|13|14|11|100|2             2       False     2.96
# 90  0.5|0.6|0.5|12|14|15|100|2             2       False     2.96
# 91  0.5|0.6|0.5|11|14|12|100|2             2       False     2.96
# 92  0.5|0.7|0.5|13|13|12|100|2             2       False     2.96

# %%
print(df[df.Value == df.Value.median()])
# Out:
#                    Date  Value  \
# 20   11/18/2022 7:50 PM    0.5
# 21   11/18/2022 7:40 PM    0.5
# 22   11/18/2022 7:30 PM    0.5
# 23   11/18/2022 7:20 PM    0.5
# 24   11/18/2022 7:10 PM    0.5
# 25   11/18/2022 7:00 PM    0.5
# 26   11/18/2022 6:50 PM    0.5
# 27   11/18/2022 6:40 PM    0.5
# 28   11/18/2022 6:30 PM    0.5
# 29   11/18/2022 6:20 PM    0.5
# 30   11/18/2022 6:10 PM    0.5
# 33   11/18/2022 5:40 PM    0.5
# 35   11/18/2022 5:20 PM    0.5
# 36   11/18/2022 5:10 PM    0.5
# 37   11/18/2022 5:00 PM    0.5
# 38   11/18/2022 4:50 PM    0.5
# 39   11/18/2022 4:40 PM    0.5
# 40   11/18/2022 4:30 PM    0.5
# 41   11/18/2022 4:20 PM    0.5
# 44   11/18/2022 3:50 PM    0.5
# 45   11/18/2022 3:40 PM    0.5
# 46   11/18/2022 3:30 PM    0.5
# 47   11/18/2022 3:20 PM    0.5
# 50   11/18/2022 2:50 PM    0.5
# 51   11/18/2022 2:40 PM    0.5
# 52   11/18/2022 2:30 PM    0.5
# 53   11/18/2022 2:20 PM    0.5
# 56   11/18/2022 1:50 PM    0.5
# 57   11/18/2022 1:40 PM    0.5
# 58   11/18/2022 1:30 PM    0.5
# 59   11/18/2022 1:20 PM    0.5
# 62  11/18/2022 12:50 PM    0.5
# 63  11/18/2022 12:40 PM    0.5
# 64  11/18/2022 12:30 PM    0.5
# 65  11/18/2022 12:20 PM    0.5
# 68  11/18/2022 11:50 AM    0.5
# 69  11/18/2022 11:40 AM    0.5
# 70  11/18/2022 11:30 AM    0.5
# 71  11/18/2022 11:20 AM    0.5
# 74  11/18/2022 10:50 AM    0.5
# 75  11/18/2022 10:40 AM    0.5
# 76  11/18/2022 10:30 AM    0.5
# 77  11/18/2022 10:20 AM    0.5
# 78  11/18/2022 10:10 AM    0.5
# 81   11/18/2022 9:40 AM    0.5
# 82   11/18/2022 9:30 AM    0.5
# 83   11/18/2022 9:20 AM    0.5
# 85   11/18/2022 9:00 AM    0.5
# 86   11/18/2022 8:50 AM    0.5
# 87   11/18/2022 8:40 AM    0.5
# 88   11/18/2022 8:30 AM    0.5
# 89   11/18/2022 8:20 AM    0.5
# 90   11/18/2022 8:10 AM    0.5
# 91   11/18/2022 8:00 AM    0.5
# 92   11/18/2022 7:50 AM    0.5
#
#                                       Formatted Value  \
# 20  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 21  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.8 mm/s 10 Hz, ...
# 22  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 23  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 15 Hz, ...
# 24  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.8 mm/s 14 Hz, ...
# 25  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 26  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.7 mm/s 16 Hz, ...
# 27  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 11 Hz, ...
# 28  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 12 Hz, ...
# 29  X-Axis 0.5 mm/s 15 Hz, Y-Axis 0.7 mm/s 15 Hz, ...
# 30  X-Axis 0.5 mm/s 10 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 33  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 35  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 36  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 37  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 14 Hz, ...
# 38  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 39  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.9 mm/s 12 Hz, ...
# 40  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.8 mm/s 10 Hz, ...
# 41  X-Axis 0.5 mm/s 10 Hz, Y-Axis 1 mm/s 11 Hz, Z-...
# 44  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.9 mm/s 12 Hz, ...
# 45  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.7 mm/s 14 Hz, ...
# 46  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 47  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 50  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.8 mm/s 13 Hz, ...
# 51  X-Axis 0.5 mm/s 15 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 52  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 53  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 56  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.8 mm/s 12 Hz, ...
# 57  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 12 Hz, ...
# 58  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.8 mm/s 12 Hz, ...
# 59  X-Axis 0.5 mm/s 16 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 62  X-Axis 0.5 mm/s 16 Hz, Y-Axis 0.8 mm/s 12 Hz, ...
# 63  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.8 mm/s 14 Hz, ...
# 64  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 15 Hz, ...
# 65  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 68  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 15 Hz, ...
# 69  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.8 mm/s 12 Hz, ...
# 70  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 71  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 13 Hz, ...
# 74  X-Axis 0.5 mm/s 15 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 75  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 76  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 77  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 11 Hz, ...
# 78  X-Axis 0.5 mm/s 15 Hz, Y-Axis 0.8 mm/s 11 Hz, ...
# 81  X-Axis 0.5 mm/s 15 Hz, Y-Axis 0.8 mm/s 12 Hz, ...
# 82  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
# 83  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.8 mm/s 14 Hz, ...
# 85  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.9 mm/s 14 Hz, ...
# 86  X-Axis 0.5 mm/s 10 Hz, Y-Axis 0.6 mm/s 12 Hz, ...
# 87  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.7 mm/s 12 Hz, ...
# 88  X-Axis 0.5 mm/s 14 Hz, Y-Axis 0.6 mm/s 12 Hz, ...
# 89  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.6 mm/s 14 Hz, ...
# 90  X-Axis 0.5 mm/s 12 Hz, Y-Axis 0.6 mm/s 14 Hz, ...
# 91  X-Axis 0.5 mm/s 11 Hz, Y-Axis 0.6 mm/s 14 Hz, ...
# 92  X-Axis 0.5 mm/s 13 Hz, Y-Axis 0.7 mm/s 13 Hz, ...
#
#                       Raw Data  Sensor State  Alert Sent  Voltage
# 20  0.5|0.8|0.6|13|11|14|100|2             2       False     2.96
# 21  0.5|0.8|0.5|11|10|13|100|2             2       False     2.96
# 22  0.5|0.8|0.6|12|11|12|100|2             2       False     2.96
# 23  0.5|0.7|0.5|13|15|13|100|2             2       False     2.96
# 24  0.5|0.8|0.6|14|14|12|100|2             2       False     2.96
# 25  0.5|0.7|0.6|12|11|14|100|2             2       False     2.96
# 26  0.5|0.7|0.5|14|16|12|100|2             2       False     2.96
# 27  0.5|0.9|0.6|12|11|14|100|2             2       False     2.96
# 28  0.5|0.7|0.6|12|12|11|100|2             2       False     2.96
# 29  0.5|0.7|0.6|15|15|12|100|2             2       False     2.96
# 30  0.5|0.9|0.6|10|13|14|100|2             2       False     2.96
# 33  0.5|0.8|0.6|13|11|12|100|2             2       False     2.96
# 35  0.5|0.7|0.5|13|13|13|100|2             2       False     2.96
# 36  0.5|0.9|0.6|11|13|12|100|2             2       False     2.96
# 37  0.5|0.9|0.6|12|14|12|100|2             2       False     2.96
# 38  0.5|0.9|0.7|13|13|15|100|2             2       False     2.96
# 39  0.5|0.9|0.5|13|12|15|100|2             2       False     2.96
# 40  0.5|0.8|0.6|14|10|13|100|2             2       False     2.96
# 41    0.5|1|0.6|10|11|12|100|2             2       False     2.96
# 44  0.5|0.9|0.6|13|12|13|100|2             2       False     2.96
# 45  0.5|0.7|0.6|11|14|12|100|2             2       False     2.96
# 46  0.5|0.7|0.6|13|13|13|100|2             2       False     2.96
# 47  0.5|0.7|0.6|12|11|15|100|2             2       False     2.96
# 50  0.5|0.8|0.5|13|13|12|100|2             2       False     2.96
# 51  0.5|0.7|0.6|15|11|10|100|2             2       False     2.96
# 52  0.5|0.7|0.5|13|11|10|100|2             2       False     2.97
# 53  0.5|0.9|0.6|12|13|12|100|2             2       False     2.96
# 56  0.5|0.8|0.6|12|12|13|100|2             2       False     2.97
# 57  0.5|0.7|0.6|13|12|13|100|2             2       False     2.96
# 58  0.5|0.8|0.6|12|12|14|100|2             2       False     2.96
# 59  0.5|0.7|0.5|16|11|12|100|2             2       False     2.96
# 62  0.5|0.8|0.6|16|12|15|100|2             2       False     2.96
# 63  0.5|0.8|0.6|14|14|12|100|2             2       False     2.96
# 64  0.5|0.7|0.6|12|15|13|100|2             2       False     2.96
# 65  0.5|0.9|0.7|14|13|11|100|2             2       False     2.96
# 68  0.5|0.9|0.6|12|15|13|100|2             2       False     2.96
# 69  0.5|0.8|0.6|11|12|12|100|2             2       False     2.96
# 70  0.5|0.7|0.5|13|13|13|100|2             2       False     2.96
# 71  0.5|0.9|0.6|12|13|13|100|2             2       False     2.96
# 74  0.5|0.7|0.5|15|13|16|100|2             2       False     2.96
# 75  0.5|0.7|0.6|14|13|13|100|2             2       False     2.96
# 76  0.5|0.7|0.6|13|11|17|100|2             2       False     2.96
# 77  0.5|0.7|0.5|13|11|13|100|2             2       False     2.96
# 78  0.5|0.8|0.6|15|11|11|100|2             2       False     2.96
# 81  0.5|0.8|0.6|15|12|12|100|2             2       False     2.96
# 82  0.5|0.7|0.6|12|13|12|100|2             2       False     2.96
# 83  0.5|0.8|0.7|11|14|15|100|2             2       False     2.96
# 85  0.5|0.9|0.6|12|14|14|100|2             2       False     2.96
# 86  0.5|0.6|0.6|10|12|11|100|2             2       False     2.96
# 87  0.5|0.7|0.5|12|12|12|100|2             2       False     2.96
# 88  0.5|0.6|0.5|14|12|14|100|2             2       False     2.96
# 89  0.5|0.6|0.5|13|14|11|100|2             2       False     2.96
# 90  0.5|0.6|0.5|12|14|15|100|2             2       False     2.96
# 91  0.5|0.6|0.5|11|14|12|100|2             2       False     2.96
# 92  0.5|0.7|0.5|13|13|12|100|2             2       False     2.96
